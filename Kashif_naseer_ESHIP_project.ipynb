# %%
# PHASE 1
# !pip install pandas numpy matplotlib seaborn textblob nltk emoji
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Load JSON files
sapphire_path = r"C:\Users\Kashif Naseer\OneDrive\Desktop\sapphire.json"
khaadi_path = r"C:\Users\Kashif Naseer\OneDrive\Desktop\khaadi.json"

try:
    sapphire_df = pd.read_json(sapphire_path)
    khaadi_df = pd.read_json(khaadi_path)

    print("🟦 Sapphire Comments:")
    display(sapphire_df.head())

    print("\n🧵 Khaadi Comments:")
    display(khaadi_df.head())

except ValueError as e:
    print("❗ It seems the JSON is nested or not in a directly readable format.")
    import json
    from pandas import json_normalize

    # Load manually with json
    with open(sapphire_path, 'r', encoding='utf-8') as f:
        sapphire_json = json.load(f)
    sapphire_df = json_normalize(sapphire_json)

    with open(khaadi_path, 'r', encoding='utf-8') as f:
        khaadi_json = json.load(f)
    khaadi_df = json_normalize(khaadi_json)

    print("🟦 Sapphire Comments (Normalized):")
    display(sapphire_df.head())

    print("\n🧵 Khaadi Comments (Normalized):")
    display(khaadi_df.head())
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import json
from pandas import json_normalize

# File paths
sapphire_path = r"C:\Users\Kashif Naseer\OneDrive\Desktop\sapphire.json"
khaadi_path = r"C:\Users\Kashif Naseer\OneDrive\Desktop\khaadi.json"

# Load JSON data
with open(sapphire_path, 'r', encoding='utf-8') as f:
    sapphire_data = json.load(f)
sapphire_df = json_normalize(sapphire_data)

with open(khaadi_path, 'r', encoding='utf-8') as f:
    khaadi_data = json.load(f)
khaadi_df = json_normalize(khaadi_data)

# Extract 'firstComment' from both datasets
sapphire_comments = sapphire_df['firstComment'].dropna()
khaadi_comments = khaadi_df['firstComment'].dropna()

# Combine and clean
all_comments = pd.concat([sapphire_comments, khaadi_comments], ignore_index=True)
all_comments = all_comments.drop_duplicates().reset_index(drop=True)

# Final DataFrame
df = pd.DataFrame({'comment': all_comments})

# Display the first few rows
display(df.head())
# Out:
#   Cell In[7], line 2
#     os.chdir("C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship")  # Replace with the path to your JSON files
#                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import re

def clean_comment(text):
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)      # Remove digits
    text = text.lower().strip()          # Lowercase and trim
    return text

df['cleaned_comment'] = df['comment'].apply(clean_comment)
display(df.head())
# Out:
#                                 comment                     cleaned_comment
# 0                                    😍😍
# 1  Sapphire apka Eid volume kb aye ga??  sapphire apka eid volume kb aye ga
# 2                                    Pp                                  pp
# 3                                  ❤️❤️
# 4                Beautiful ❤️❤️❤️❤️❤️❤️                           beautiful

# %%
# !pip install pandas numpy matplotlib seaborn textblob nltk emoji

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import emoji
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [nltk_data] Downloading package stopwords to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Kashif
# [nltk_data]     Naseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
import os

# Set your custom download path (using raw string)
project_nltk_path = r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\nlk"

# Append the path to NLTK data path
nltk.data.path.append(project_nltk_path)

# Create the folder if it doesn't exist
os.makedirs(project_nltk_path, exist_ok=True)
print(f"Directory created or exists: {project_nltk_path}")

# Download required corpora to your project path
try:
    nltk.download('punkt', download_dir=project_nltk_path)
    nltk.download('stopwords', download_dir=project_nltk_path)
    print("Downloads completed successfully.")
except Exception as e:
    print(f"Error downloading NLTK data: {e}")

# Test the setup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Test tokenization
sample_text = "This is a test sentence."
tokens = word_tokenize(sample_text)
print("Tokens:", tokens)

# Test stopwords
stop_words = set(stopwords.words('english'))
print("Stopwords sample:", list(stop_words)[:5])

# Verify NLTK data path
print("NLTK data paths:", nltk.data.path)
# Out:
# Directory created or exists: C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\nlk
# [nltk_data] Downloading package punkt to C:\Users\Kashif
# [nltk_data]     Naseer\OneDrive\Desktop\21F-9306_eship\nlk...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Kashif
# [nltk_data]     Naseer\OneDrive\Desktop\21F-9306_eship\nlk...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# Downloads completed successfully.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[14], line 28
#      26 # Test tokenization
#      27 sample_text = "This is a test sentence."
# ---> 28 tokens = word_tokenize(sample_text)
#      29 print("Tokens:", tokens)
#      31 # Test stopwords
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
# ...

# %%
import pandas as pd
import re
import string
import emoji
from tabulate import tabulate

# Load the JSON files
try:
    df_sapphire = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sapphire.json")
    df_khaadi = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\khaadi.json")
except Exception as e:
    print(f"Error loading JSON files: {e}")
    exit()

# Combine both datasets (assuming both have a 'comment_text' column)
try:
    df = pd.concat([df_sapphire, df_khaadi], ignore_index=True)
except Exception as e:
    print(f"Error combining datasets: {e}")
    exit()

# Verify that 'comment_text' column exists
if 'comment_text' not in df.columns:
    print("Column 'comment_text' not found in the dataset. Available columns:", df.columns)
    exit()

# Define simple stopwords list (you can expand this as needed)
custom_stopwords = set([
    "the", "is", "at", "which", "on", "and", "a", "an", "of", "this", "that", "in", "to", "for"
])

# Clean function without nltk
def clean_comment(text):
    if not isinstance(text, str):
        return ""

    # Remove emojis
    text = emoji.replace_emoji(text, replace="")

    # Remove URLs
    text = re.sub(r"http\S+|www.\S+", "", text)

    # Remove punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Lowercase
    text = text.lower()

    # Tokenize and remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word.isalpha() and word not in custom_stopwords]

    return " ".join(tokens)

# Apply cleaning function
df['cleaned_comment'] = df['comment_text'].apply(clean_comment)

# Display the first few rows of original and cleaned comments in a formatted table
print("\nCleaned Comments Table:")
print(tabulate(df[['comment_text', 'cleaned_comment']].head(), headers=['Original Comment', 'Cleaned Comment'], tablefmt='grid', showindex=False))
# Out:
# Column 'comment_text' not found in the dataset. Available columns: Index(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags',
#        'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments',
#        'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'alt',
#        'likesCount', 'timestamp', 'childPosts', 'ownerFullName',
#        'ownerUsername', 'ownerId', 'isSponsored', 'videoUrl', 'videoViewCount',
#        'videoPlayCount', 'productType', 'videoDuration', 'musicInfo',
#        'taggedUsers', 'coauthorProducers', 'locationName', 'locationId',
#        'isPinned'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
# ...

# %%
import pandas as pd
import re
import string
import emoji

print("Starting script...")

# Load the JSON files
try:
    print("Loading sapphire.json...")
    df_sapphire = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sapphire.json")
    print("Loading khaadi.json...")
    df_khaadi = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\khaadi.json")
except Exception as e:
    print(f"Error loading JSON files: {e}")
    exit()

# Combine both datasets
try:
    print("Combining datasets...")
    df = pd.concat([df_sapphire, df_khaadi], ignore_index=True)
    print("Combined DataFrame created with shape:", df.shape)
except Exception as e:
    print(f"Error combining datasets: {e}")
    exit()

# Verify that 'comment_text' column exists
if 'comment_text' not in df.columns:
    print("Column 'comment_text' not found in the dataset. Available columns:", df.columns)
    exit()
else:
    print("Found 'comment_text' column.")

# Define simple stopwords list
custom_stopwords = set([
    "the", "is", "at", "which", "on", "and", "a", "an", "of", "this", "that", "in", "to", "for"
])

# Clean function without nltk
def clean_comment(text):
    if not isinstance(text, str):
        return ""
    text = emoji.replace_emoji(text, replace="")
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.lower()
    tokens = text.split()
    tokens = [word for word in tokens if word.isalpha() and word not in custom_stopwords]
    return " ".join(tokens)

# Apply cleaning function
print("Cleaning comments...")
df['cleaned_comment'] = df['comment_text'].apply(clean_comment)
print("Cleaning complete. Sample data:")
print(df[['comment_text', 'cleaned_comment']].head())
# Out:
# Starting script...
# Loading sapphire.json...
# Loading khaadi.json...
# Combining datasets...
# Combined DataFrame created with shape: (800, 34)
# Column 'comment_text' not found in the dataset. Available columns: Index(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags',
#        'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments',
#        'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'alt',
#        'likesCount', 'timestamp', 'childPosts', 'ownerFullName',
#        'ownerUsername', 'ownerId', 'isSponsored', 'videoUrl', 'videoViewCount',
#        'videoPlayCount', 'productType', 'videoDuration', 'musicInfo',
#        'taggedUsers', 'coauthorProducers', 'locationName', 'locationId',
#        'isPinned'],
#       dtype='object')
# Cleaning comments...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
# ... code that creates df ...
# Your snippet
df.to_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\cleaned_fashion_comments.json", orient="records", lines=True, index=False)
print("✅ Cleaned data saved as cleaned_fashion_comments.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 # ... code that creates df ...
#       3 # Your snippet
# ----> 4 df.to_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\cleaned_fashion_comments.json", orient="records", lines=True, index=False)
#       5 print("✅ Cleaned data saved as cleaned_fashion_comments.json")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import re
import string
import emoji

print("Starting Phase 1 script...")

# Load the JSON files
try:
    print("Loading sapphire.json...")
    df_sapphire = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sapphire.json")
    print("Loading khaadi.json...")
    df_khaadi = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\khaadi.json")
except Exception as e:
    print(f"Error loading JSON files: {e}")
    exit()

# Combine both datasets
try:
    print("Combining datasets...")
    df = pd.concat([df_sapphire, df_khaadi], ignore_index=True)
    print("Combined DataFrame created with shape:", df.shape)
    print("Columns in combined DataFrame:", df.columns.tolist())
except Exception as e:
    print(f"Error combining datasets: {e}")
    exit()

# Verify that 'latestComments' column exists
if 'latestComments' not in df.columns:
    print("Column 'latestComments' not found in the dataset. Available columns:", df.columns.tolist())
    print("Please update the script with the correct column name and rerun.")
    exit()
else:
    print("Found 'latestComments' column.")

# Define simple stopwords list
custom_stopwords = set([
    "the", "is", "at", "which", "on", "and", "a", "an", "of", "this", "that", "in", "to", "for"
])

# Clean function without nltk
def clean_comment(text):
    if not isinstance(text, str):
        return ""
    text = emoji.replace_emoji(text, replace="")
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.lower()
    tokens = text.split()
    tokens = [word for word in tokens if word.isalpha() and word not in custom_stopwords]
    return " ".join(tokens)

# Extract and clean comments from latestComments
def extract_and_clean_comments(comments):
    if isinstance(comments, list):
        # Extract 'text' field from each comment and clean it
        cleaned_texts = [clean_comment(c.get('text', '')) for c in comments if isinstance(c, dict) and 'text' in c]
        # Join all cleaned comments into a single string, excluding empty strings
        return " ".join([text for text in cleaned_texts if text])
    return ""

# Apply extraction and cleaning
print("Extracting and cleaning comments from latestComments...")
df['cleaned_comment'] = df['latestComments'].apply(extract_and_clean_comments)
print("Cleaning complete. Sample data:")
print(df[['latestComments', 'cleaned_comment']].head())

# Save the cleaned version to JSON
try:
    print("Saving to JSON...")
    df.to_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\cleaned_fashion_comments.json", orient="records", lines=True)
    print("✅ Cleaned data saved as cleaned_fashion_comments.json")
except Exception as e:
    print(f"Error saving JSON file: {e}")
    exit()
# Out:
# Starting Phase 1 script...
# Loading sapphire.json...
# Loading khaadi.json...
# Combining datasets...
# Combined DataFrame created with shape: (800, 34)
# Columns in combined DataFrame: ['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags', 'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments', 'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'alt', 'likesCount', 'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId', 'isSponsored', 'videoUrl', 'videoViewCount', 'videoPlayCount', 'productType', 'videoDuration', 'musicInfo', 'taggedUsers', 'coauthorProducers', 'locationName', 'locationId', 'isPinned']
# Found 'latestComments' column.
# Extracting and cleaning comments from latestComments...
# Cleaning complete. Sample data:
#                                       latestComments  \
# 0  [{'id': '18076904308761189', 'text': '😍😍', 'ow...
# 1  [{'id': '18064916062990459', 'text': 'Sapphire...
# ...

# %%
from textblob import TextBlob

# Calculate sentiment
def get_sentiment(text):
    if text:
        return TextBlob(text).sentiment.polarity  # Returns -1 (negative) to 1 (positive)
    return 0

print("Calculating sentiment...")
df['sentiment'] = df['cleaned_comment'].apply(get_sentiment)
print("Sentiment analysis complete. Sample data:")
print(df[['cleaned_comment', 'sentiment']].head())
# Out:
# Calculating sentiment...
# Sentiment analysis complete. Sample data:
#                                      cleaned_comment  sentiment
# 0  pp price its all available online price articl...   0.400000
# 1  sapphire apka eid volume kb aye ga sapphirepak...   0.146703
# 2  pp phansi latka den aiza ko phr sahi modlling ...   0.000000
# 3             agr apko mily link kindly also send me   0.600000
# 4  beautiful truly versatile actress generation q...   0.616667

# %%
df['brand'] = ['Sapphire'] * len(df_sapphire) + ['Khaadi'] * len(df_khaadi)
print("Added 'brand' column. Sample data:")
print(df[['brand', 'cleaned_comment', 'sentiment']].head())
# Out:
# Added 'brand' column. Sample data:
#       brand                                    cleaned_comment  sentiment
# 0  Sapphire  pp price its all available online price articl...   0.400000
# 1  Sapphire  sapphire apka eid volume kb aye ga sapphirepak...   0.146703
# 2  Sapphire  pp phansi latka den aiza ko phr sahi modlling ...   0.000000
# 3  Sapphire             agr apko mily link kindly also send me   0.600000
# 4  Sapphire  beautiful truly versatile actress generation q...   0.616667

# %%
import pandas as pd
import re
import string
import emoji
from textblob import TextBlob

print("Starting script...")

# Load the JSON files
try:
    print("Loading sapphire.json...")
    df_sapphire = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sapphire.json")
    print("Loading khaadi.json...")
    df_khaadi = pd.read_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\khaadi.json")
except Exception as e:
    print(f"Error loading JSON files: {e}")
    exit()

# Combine both datasets
try:
    print("Combining datasets...")
    df = pd.concat([df_sapphire, df_khaadi], ignore_index=True)
    print("Combined DataFrame created with shape:", df.shape)
    print("Columns in combined DataFrame:", df.columns.tolist())
except Exception as e:
    print(f"Error combining datasets: {e}")
    exit()

# Verify that 'latestComments' column exists
if 'latestComments' not in df.columns:
    print("Column 'latestComments' not found in the dataset. Available columns:", df.columns.tolist())
    exit()
else:
    print("Found 'latestComments' column.")

# Define simple stopwords list
custom_stopwords = set([
    "the", "is", "at", "which", "on", "and", "a", "an", "of", "this", "that", "in", "to", "for"
])

# Clean function without nltk
def clean_comment(text):
    if not isinstance(text, str):
        return ""
    text = emoji.replace_emoji(text, replace="")
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.lower()
    tokens = text.split()
    tokens = [word for word in tokens if word.isalpha() and word not in custom_stopwords]
    return " ".join(tokens)

# Extract and clean comments from latestComments
def extract_and_clean_comments(comments):
    if isinstance(comments, list):
        cleaned_texts = [clean_comment(c.get('text', '')) for c in comments if isinstance(c, dict) and 'text' in c]
        return " ".join([text for text in cleaned_texts if text])
    return ""

# Apply extraction and cleaning
print("Extracting and cleaning comments from latestComments...")
df['cleaned_comment'] = df['latestComments'].apply(extract_and_clean_comments)
print("Cleaning complete. Sample data:")
print(df[['latestComments', 'cleaned_comment']].head())

# Calculate sentiment
def get_sentiment(text):
    if text:
        return TextBlob(text).sentiment.polarity  # Returns -1 (negative) to 1 (positive)
    return 0

print("Calculating sentiment...")
df['sentiment'] = df['cleaned_comment'].apply(get_sentiment)
print("Sentiment analysis complete. Sample data:")
print(df[['cleaned_comment', 'sentiment']].head())

# Add brand column
df['brand'] = ['Sapphire'] * len(df_sapphire) + ['Khaadi'] * len(df_khaadi)
print("Added 'brand' column. Sample data:")
print(df[['brand', 'cleaned_comment', 'sentiment']].head())
# Out:
# Starting script...
# Loading sapphire.json...
# Loading khaadi.json...
# Combining datasets...
# Combined DataFrame created with shape: (800, 34)
# Columns in combined DataFrame: ['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags', 'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments', 'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'alt', 'likesCount', 'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId', 'isSponsored', 'videoUrl', 'videoViewCount', 'videoPlayCount', 'productType', 'videoDuration', 'musicInfo', 'taggedUsers', 'coauthorProducers', 'locationName', 'locationId', 'isPinned']
# Found 'latestComments' column.
# Extracting and cleaning comments from latestComments...
# Cleaning complete. Sample data:
#                                       latestComments  \
# 0  [{'id': '18076904308761189', 'text': '😍😍', 'ow...
# 1  [{'id': '18064916062990459', 'text': 'Sapphire...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of sentiment scores
plt.figure(figsize=(12, 5))
sns.histplot(df['sentiment'], bins=20)
plt.title('Sentiment Distribution of Fashion Comments')
plt.xlabel('Sentiment Score')
plt.ylabel('Count')
plt.savefig(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sentiment_histogram.png")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Sentiment over time
if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    time_trend = df.groupby([df['timestamp'].dt.date, 'brand'])['sentiment'].mean().unstack()
    plt.figure(figsize=(12, 5))
    time_trend.plot()
    plt.title('Sentiment Trend Over Time by Brand')
    plt.xlabel('Date')
    plt.ylabel('Average Sentiment')
    plt.savefig(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sentiment_trend.png")
    plt.show()
else:
    print("No 'timestamp' column found. Skipping time trend plot.")

# %%
# Box plot of sentiment by brand
plt.figure(figsize=(12, 5))
sns.boxplot(x='brand', y='sentiment', data=df)
plt.title('Sentiment Comparison: Sapphire vs. Khaadi')
plt.xlabel('Brand')
plt.ylabel('Sentiment Score')
plt.savefig(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sentiment_boxplot.png")
plt.show()

# %%
# Categorize sentiment into positive, negative, neutral
def categorize_sentiment(score):
    if score > 0:
        return 'Positive'
    elif score < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply categorization
df['sentiment_category'] = df['sentiment'].apply(categorize_sentiment)

# Calculate proportions
sentiment_counts = df['sentiment_category'].value_counts()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['#66b3ff', '#ff9999', '#99ff99'])
plt.title('Sentiment Distribution of Fashion Comments')
plt.savefig(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sentiment_pie_chart.png")
plt.show()

# %%
# Violin plot of sentiment by brand
plt.figure(figsize=(12, 5))
sns.violinplot(x='brand', y='sentiment', data=df, inner='quartile')
plt.title('Sentiment Polarity Score Distribution by Brand')
plt.xlabel('Brand')
plt.ylabel('Sentiment Polarity Score')
plt.savefig(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\sentiment_violinplot.png")
plt.show()

# %%
# Save the DataFrame with sentiment, brand, and sentiment category
try:
    print("Saving to JSON with sentiment...")
    df.to_json(r"C:\Users\Kashif Naseer\OneDrive\Desktop\21F-9306_eship\cleaned_fashion_comments_with_sentiment.json", orient="records", lines=True)
    print("✅ Cleaned data with sentiment saved as cleaned_fashion_comments_with_sentiment.json")
except Exception as e:
    print(f"Error saving JSON file: {e}")
    exit()
# Out:
# Saving to JSON with sentiment...
# ✅ Cleaned data with sentiment saved as cleaned_fashion_comments_with_sentiment.json
